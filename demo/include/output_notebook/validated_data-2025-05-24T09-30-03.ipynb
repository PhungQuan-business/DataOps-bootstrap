# %%
# Parameters
execution_date = "2025-05-24 09:30:03.190333+00:00"

# %%
# Install pakcage if not installed
# pip install great-expectations -q

# %%
import great_expectations as gx
import great_expectations.expectations as gxe
import os

# %% [markdown]
# ## Define Data Context

# %%
# context = gx.get_context(mode="file")
# Retrieve your Data Context
context = gx.get_context(mode="ephemeral") # Please choose one of: ephemeral, file, cloud.
print(type(context).__name__ )
assert type(context).__name__ == "EphemeralDataContext" # Please choose one of: FileDataContext, EphemeralDataContext, CloudDataContext
# Out:
# EphemeralDataContext

# %% [markdown]
# ## Define Data Source

# %%
import great_expectations as gx

# Define the Data Source name
data_source_name = "canada_data_source"

# Add the Data Source to the Data Context
data_source = context.data_sources.add_pandas(name=data_source_name)
assert data_source.name == data_source_name

# %% [markdown]
# ## Define Data Assest

# %%
import great_expectations as gx

# Retrieve the Data Source
data_source_name = "canada_data_source"
data_source = context.data_sources.get(data_source_name)

# Define the Data Asset name
data_asset_name = "canada_data_asset"

# Add a Data Asset to the Data Source
data_asset = data_source.add_dataframe_asset(name=data_asset_name)

assert data_asset.name == data_asset_name

# %% [markdown]
# ## Define Batch Definition

# %%
import great_expectations as gx

# Retrieve the Data Asset
data_source_name = "canada_data_source"
data_asset_name = "canada_data_asset"
data_asset = context.data_sources.get(data_source_name).get_asset(data_asset_name)

# Define the Batch Definition name
batch_definition_name = "canada_batch_definition"

# Add a Batch Definition to the Data Asset
batch_definition = data_asset.add_batch_definition_whole_dataframe(
    batch_definition_name
)
assert batch_definition.name == batch_definition_name

# %%
import great_expectations as gx

# Retrieve the dataframe Batch Definition
data_source_name = "canada_data_source"
data_asset_name = "canada_data_asset"
batch_definition_name = "canada_batch_definition"
batch_definition = (
    context.data_sources.get(data_source_name)
    .get_asset(data_asset_name)
    .get_batch_definition(batch_definition_name)
)

# %% [markdown]
# ## Define Expectations

# %%
expectations = [
    gx.expectations.ExpectTableColumnCountToEqual(value=396),
    gx.expectations.ExpectTableColumnsToMatchSet(
        column_set=[
            "streetAddress", "addressLocality", "addressRegion", "postalCode",
            "latitude", "longitude", "description", "price", "priceCurrency", "property-beds"
        ],
        # column_set=[column_list],
        exact_match=True
    ),
    gx.expectations.ExpectColumnValuesToBeOfType(column="latitude", type_="float64"),
    gx.expectations.ExpectColumnValuesToBeOfType(column="longitude", type_="float64"),
    gx.expectations.ExpectColumnValuesToBeOfType(column="streetAddress", type_="object"),
    gx.expectations.ExpectColumnValuesToBeOfType(column="price", type_="float64"),
    gx.expectations.ExpectColumnValuesToBeOfType(column="property-beds", type_="float64")
]

# %% [markdown]
# ## Define Batch Parameters

# %%
import pandas as pd

DATA_DIR = os.environ.get('DATA_PATH')
DATA_PATH = f'{DATA_DIR}/small_canada.csv'

small_dataframe = pd.read_csv(DATA_PATH, index_col=False)
# yt_dataframe = pd.read_csv('/content/drive/MyDrive/linh tinh/canada-data-small/data_yt.csv', index_col=False)

# remove 10th column of yt_dataframe
# modified_yt_dataframe = yt_dataframe.iloc[:, :-1]

small_batch_parameters = {"dataframe": small_dataframe}
# yt_batch_parameters = {"dataframe": yt_dataframe}
# modified_yt_batch_parameters = {"dataframe": modified_yt_dataframe}
# Out:
# /tmp/ipykernel_242214/988729941.py:6: DtypeWarning: Columns (43,77,88,94,260) have mixed types. Specify dtype option on import or set low_memory=False.
#   small_dataframe = pd.read_csv(DATA_PATH, index_col=False)

# %%
small_batch = batch_definition.get_batch(batch_parameters=small_batch_parameters)
# yt_batch = batch_definition.get_batch(batch_parameters=yt_batch_parameters)
# modified_yt_batch = batch_definition.get_batch(batch_parameters=modified_yt_batch_parameters)

# %% [markdown]
# ## Validate expectations

# %%
# Run them
for exp in expectations:
    result = small_batch.validate(exp)
    if not result["success"]:
        print("❌ Validation failed:")
        print(result)
# Out:
# Calculating Metrics:   0%|          | 0/3 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/3 [00:00<?, ?it/s]
# Calculating Metrics:  33%|███▎      | 1/3 [00:00<00:00, 2477.44it/s]
# Calculating Metrics:  33%|███▎      | 1/3 [00:00<00:00, 1605.17it/s]
# Calculating Metrics:  67%|██████▋   | 2/3 [00:00<00:00, 2215.11it/s]
# Calculating Metrics:  67%|██████▋   | 2/3 [00:00<00:00, 1654.23it/s]
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 2189.86it/s]
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 1832.91it/s]
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 1566.99it/s]
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 1449.81it/s]
# ❌ Validation failed:
# {
#   "success": false,
#   "expectation_config": {
#     "type": "expect_table_column_count_to_equal",
#     "kwargs": {
#       "batch_id": "canada_data_source-canada_data_asset",
#       "value": 396
#     },
#     "meta": {}
#   },
#   "result": {
#     "observed_value": 397
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# Calculating Metrics:  50%|█████     | 1/2 [00:00<00:00, 3095.43it/s]
# Calculating Metrics:  50%|█████     | 1/2 [00:00<00:00, 2133.42it/s]
# Calculating Metrics: 100%|██████████| 2/2 [00:00<00:00, 3323.54it/s]
# Calculating Metrics: 100%|██████████| 2/2 [00:00<00:00, 2791.55it/s]
# Calculating Metrics: 100%|██████████| 2/2 [00:00<00:00, 1710.56it/s]
# Calculating Metrics: 100%|██████████| 2/2 [00:00<00:00, 1423.00it/s]
# ❌ Validation failed:
# {
#   "success": false,
#   "expectation_config": {
#     "type": "expect_table_columns_to_match_set",
#     "kwargs": {
#       "batch_id": "canada_data_source-canada_data_asset",
#       "column_set": [
#         "streetAddress",
#         "addressLocality",
#         "addressRegion",
#         "postalCode",
#         "latitude",
#         "longitude",
#         "description",
#         "price",
#         "priceCurrency",
#         "property-beds"
#       ]
#     },
#     "meta": {}
#   },
#   "result": {
#     "observed_value": [
#       "2nd Br Description",
#       "3rd Br Description",
#       "4th Br Description",
#       "5th Br Description",
#       "Access",
#       "Access Road",
#       "Acreage",
#       "Acreage Range",
#       "Age Description",
#       "Air Conditioning",
#       "Amenities",
#       "Appliances",
#       "Approx Age",
#       "Architectural Style",
#       "Architecture",
#       "Area",
#       "Assessed Fees",
#       "Assoc",
#       "Assoc/Maint Fee Per",
#       "Association Amenities",
#       "Association Fee Frequency",
#       "Balcony",
#       "Bare Land YN",
#       "Basement",
#       "Basement Description",
#       "Basement Details",
#       "Basement Development",
#       "Basement Type",
#       "Basement Walls",
#       "Bath",
#       "Bath 2-Piece Level",
#       "Bath 3-Piece Level",
#       "Bath 4-Piece Level",
#       "Bathroom Description",
#       "Bedroom",
#       "Bedroom Level",
#       "Board",
#       "Bonus Room",
#       "Br Description",
#       "Breakfast",
#       "Breakfast Description",
#       "Building Area Source",
#       "Building Features",
#       "Building Style",
#       "Building Type",
#       "Buildings",
#       "Bush",
#       "Business Type",
#       "Buyer Agent Designation",
#       "Carport",
#       "Cold/Cant Description",
#       "Commercial Type",
#       "Common Interest",
#       "Common Room Description",
#       "Community Features",
#       "Community Name",
#       "Complex",
#       "Condo Fees",
#       "Condo Fees Assessed Y/N",
#       "Condo Fees Include",
#       "Condo Management",
#       "Condo Management Firm",
#       "Condo Name",
#       "Construction",
#       "Construction Materials",
#       "Construction Type",
#       "Contract Conditions",
#       "Cooling",
#       "Covered Parking",
#       "Current Financing",
#       "Current Use",
#       "Date Listed",
#       "Den",
#       "Den Description",
#       "Dining Description",
#       "Dining Room",
#       "Dining Room Level",
#       "Dinning Description",
#       "Direction Facing",
#       "Disclosures/Documents",
#       "Distance To Elementary School",
#       "Distance To High School",
#       "Distance To Town",
#       "District",
#       "Documents On File",
#       "Double",
#       "Drinking Water Y/N",
#       "Driveway",
#       "Dues Frequency",
#       "Dwelling Type",
#       "Electric",
#       "Electric (amps)",
#       "Electric (volts)",
#       "Electric Available",
#       "Electric Paid By",
#       "Elevator",
#       "Ensuite",
#       "Ensuite 4-Piece Level",
#       "Escape Clause",
#       "Exclusions",
#       "Exercise Description",
#       "Exposure",
#       "Exterior",
#       "Exterior Build",
#       "Exterior Features",
#       "Exterior Finish",
#       "Extra Structures",
#       "FP Fuel",
#       "Family Description",
#       "Family Room",
#       "Family Room Level",
#       "Farm",
#       "Farm Type",
#       "Features",
#       "Fee Frequency",
#       "Fee Includes",
#       "Fees",
#       "Fence",
#       "Fencing",
#       "Financing",
#       "Finished Basement",
#       "Fireplace",
#       "Fireplace Description",
#       "Fireplace Features",
#       "Fireplace Fuel",
#       "Fireplace Location",
#       "Fireplace Type",
#       "Fireplace Y/N",
#       "Fireplaces",
#       "Floor Location",
#       "Flooring",
#       "For Sale or Lease",
#       "Formal Dining",
#       "Foundation",
#       "Foundation Details",
#       "Foundation/Basement",
#       "Foyer",
#       "Foyer Description",
#       "Foyer Level",
#       "Franchise",
#       "Frontage",
#       "Fronting On",
#       "Fuel",
#       "Fuel Type",
#       "Full Bathrooms",
#       "Furnace",
#       "Furnace Description",
#       "Furnished",
#       "Gallery",
#       "Game Room",
#       "Games Description",
#       "Garage",
#       "Garage Capacity",
#       "Garage Description",
#       "Garage Spaces",
#       "Garage Type",
#       "Garage/Carport",
#       "Gas",
#       "Gas Available",
#       "Gated",
#       "Grade Level Entry Y/N",
#       "Great Room",
#       "Great Room Description",
#       "HOA Includes",
#       "HOA Pay Schedule",
#       "HOA Terms",
#       "HVAC",
#       "Half Bathrooms",
#       "Heating",
#       "Heating Fuel",
#       "Heating Fuels",
#       "Heating Source",
#       "Heating/Cooling",
#       "Home Features",
#       "Hot Water",
#       "Inclusions",
#       "Income Property",
#       "Insurance Paid By",
#       "Interior",
#       "Interior Features",
#       "Interior Layout",
#       "Interior Maintenance/Repairs Paid By",
#       "Kitchen",
#       "Kitchen Description",
#       "Kitchen Level",
#       "Land Features",
#       "Last Change Type",
#       "Last Updated",
#       "Laundry",
#       "Laundry Description",
#       "Laundry Location",
#       "Laundry Room",
#       "Laundry Room Level",
#       "LaundryFeatures",
#       "Lease",
#       "Lease Includes",
#       "Lease Requirements",
#       "Lease Term",
#       "Lease Type",
#       "Levels",
#       "Library Description",
#       "Listing ID",
#       "Living Area",
#       "Living Description",
#       "Living Room",
#       "Living Room Level",
#       "Loading Dock",
#       "Loading Info",
#       "Location",
#       "Lock Box",
#       "Locker",
#       "Locker Description",
#       "Lot Description",
#       "Lot Features",
#       "Lot Measurement",
#       "Lot Shape",
#       "Lot Size",
#       "Lot Size Source",
#       "MLS",
#       "MLS Area Minor",
#       "MLS\u00ae #",
#       "Maintenance",
#       "Maintenance Paid By",
#       "Major Area",
#       "Management",
#       "Master Bath",
#       "Master Bedroom",
#       "Master Bedroom First Floor",
#       "Master Description",
#       "Media Room",
#       "Media/Ent Description",
#       "Mobile Home Type",
#       "Model Type",
#       "Mortgage Calculator",
#       "Mudroom Description",
#       "Municipality",
#       "N/A",
#       "Natural Gas",
#       "Nearest Town",
#       "Neighbourhood Features",
#       "Number Of Fireplaces",
#       "Nursery Description",
#       "Occupancy",
#       "Occupied By",
#       "Office Description",
#       "Office/Den",
#       "Other",
#       "Out Buildings",
#       "Outdoor Area",
#       "Owner Pays",
#       "Ownership",
#       "Ownership Type",
#       "Pantry Description",
#       "Parking",
#       "Parking Description",
#       "Parking Features",
#       "Parking Spaces",
#       "Parking Surface",
#       "Parking Types",
#       "Partial Bathroom",
#       "Patio",
#       "Percolation Test",
#       "Pet Policy",
#       "Pets Allowed",
#       "Play Description",
#       "Plumbing",
#       "Pool",
#       "Pool Features",
#       "Pool YN",
#       "Possession",
#       "Powder Room Description",
#       "Power",
#       "Power Source",
#       "Present Structures",
#       "Present Use",
#       "Price Type",
#       "Primary Bedrm Level",
#       "Property Details",
#       "Property Sub Type",
#       "Property Subtype",
#       "Property Tax",
#       "Property Type",
#       "Property Type Detail",
#       "Quarter",
#       "Range",
#       "Rear Exposure",
#       "Rec Description",
#       "Recreation",
#       "Recreation Room Level",
#       "Rent Includes",
#       "Rental Equipment",
#       "Rental Features",
#       "Rental Type",
#       "Residence",
#       "Restrictions",
#       "Restrictions/Covenants",
#       "Road",
#       "Road Between Waterfront And Home",
#       "Roof",
#       "Roofing",
#       "Roofing Description",
#       "Room Details",
#       "Rooms",
#       "Sale Rent",
#       "Sale Terms",
#       "Sale Type",
#       "SaleOrRent",
#       "School District",
#       "Security Features",
#       "See less details",
#       "See more details",
#       "Sewer",
#       "Sewer Type",
#       "Showing Instructions",
#       "Sign",
#       "Site Description",
#       "Site Influence",
#       "Site Influences",
#       "Site Information",
#       "Sitting Description",
#       "Smoke Detector(s)",
#       "Soil",
#       "Soil Test",
#       "Solarium Description",
#       "Sprinklers",
#       "SqFT Range",
#       "SqFt Range",
#       "Square Footage",
#       "Status",
#       "Storage Room Level",
#       "Stories",
#       "Storm Sewage Drain",
#       "Structure",
#       "Study Description",
#       "Style",
#       "Sub Area",
#       "Sub Property Type",
#       "Sub Type",
#       "Subdivision",
#       "Sunroom Description",
#       "Surface Water",
#       "Survey Available",
#       "TV Service",
#       "Tandem Description",
#       "Tax Year",
#       "Taxes Paid By",
#       "Telephone Service",
#       "Tenant Pays",
#       "Terms",
#       "Title",
#       "Topography",
#       "Total Acres",
#       "Transaction Type",
#       "Type",
#       "Unnamed: 0",
#       "Utilities",
#       "Utilities Available",
#       "Utilities Included",
#       "Utility Description",
#       "Utility Room",
#       "View",
#       "Walk In Closet Level",
#       "Waste",
#       "Water",
#       "Water Heater",
#       "Water Heater Location",
#       "Water Heating Paid By",
#       "Water Paid By",
#       "Water Purifier",
#       "Water Service",
#       "Water Softener",
#       "Water Source",
#       "Water Treatment",
#       "Water Type",
#       "Water/Sewer",
#       "Waterfront",
#       "Waterfront Features",
#       "Waterfront YN",
#       "Waterview",
#       "Workshop description",
#       "Year Built",
#       "Year Built Description",
#       "Year Built Source",
#       "Yes",
#       "Zoning",
#       "addressLocality",
#       "addressRegion",
#       "description",
#       "latitude",
#       "longitude",
#       "postalCode",
#       "price",
#       "priceCurrency",
#       "property-baths",
#       "property-beds",
#       "property-sqft",
#       "streetAddress"
#     ],
#     "details": {
#       "mismatched": {
#         "unexpected": [
#           "2nd Br Description",
#           "3rd Br Description",
#           "4th Br Description",
#           "5th Br Description",
#           "Access",
#           "Access Road",
#           "Acreage",
#           "Acreage Range",
#           "Age Description",
#           "Air Conditioning",
#           "Amenities",
#           "Appliances",
#           "Approx Age",
#           "Architectural Style",
#           "Architecture",
#           "Area",
#           "Assessed Fees",
#           "Assoc",
#           "Assoc/Maint Fee Per",
#           "Association Amenities",
#           "Association Fee Frequency",
#           "Balcony",
#           "Bare Land YN",
#           "Basement",
#           "Basement Description",
#           "Basement Details",
#           "Basement Development",
#           "Basement Type",
#           "Basement Walls",
#           "Bath",
#           "Bath 2-Piece Level",
#           "Bath 3-Piece Level",
#           "Bath 4-Piece Level",
#           "Bathroom Description",
#           "Bedroom",
#           "Bedroom Level",
#           "Board",
#           "Bonus Room",
#           "Br Description",
#           "Breakfast",
#           "Breakfast Description",
#           "Building Area Source",
#           "Building Features",
#           "Building Style",
#           "Building Type",
#           "Buildings",
#           "Bush",
#           "Business Type",
#           "Buyer Agent Designation",
#           "Carport",
#           "Cold/Cant Description",
#           "Commercial Type",
#           "Common Interest",
#           "Common Room Description",
#           "Community Features",
#           "Community Name",
#           "Complex",
#           "Condo Fees",
#           "Condo Fees Assessed Y/N",
#           "Condo Fees Include",
#           "Condo Management",
#           "Condo Management Firm",
#           "Condo Name",
#           "Construction",
#           "Construction Materials",
#           "Construction Type",
#           "Contract Conditions",
#           "Cooling",
#           "Covered Parking",
#           "Current Financing",
#           "Current Use",
#           "Date Listed",
#           "Den",
#           "Den Description",
#           "Dining Description",
#           "Dining Room",
#           "Dining Room Level",
#           "Dinning Description",
#           "Direction Facing",
#           "Disclosures/Documents",
#           "Distance To Elementary School",
#           "Distance To High School",
#           "Distance To Town",
#           "District",
#           "Documents On File",
#           "Double",
#           "Drinking Water Y/N",
#           "Driveway",
#           "Dues Frequency",
#           "Dwelling Type",
#           "Electric",
#           "Electric (amps)",
#           "Electric (volts)",
#           "Electric Available",
#           "Electric Paid By",
#           "Elevator",
#           "Ensuite",
#           "Ensuite 4-Piece Level",
#           "Escape Clause",
#           "Exclusions",
#           "Exercise Description",
#           "Exposure",
#           "Exterior",
#           "Exterior Build",
#           "Exterior Features",
#           "Exterior Finish",
#           "Extra Structures",
#           "FP Fuel",
#           "Family Description",
#           "Family Room",
#           "Family Room Level",
#           "Farm",
#           "Farm Type",
#           "Features",
#           "Fee Frequency",
#           "Fee Includes",
#           "Fees",
#           "Fence",
#           "Fencing",
#           "Financing",
#           "Finished Basement",
#           "Fireplace",
#           "Fireplace Description",
#           "Fireplace Features",
#           "Fireplace Fuel",
#           "Fireplace Location",
#           "Fireplace Type",
#           "Fireplace Y/N",
#           "Fireplaces",
#           "Floor Location",
#           "Flooring",
#           "For Sale or Lease",
#           "Formal Dining",
#           "Foundation",
#           "Foundation Details",
#           "Foundation/Basement",
#           "Foyer",
#           "Foyer Description",
#           "Foyer Level",
#           "Franchise",
#           "Frontage",
#           "Fronting On",
#           "Fuel",
#           "Fuel Type",
#           "Full Bathrooms",
#           "Furnace",
#           "Furnace Description",
#           "Furnished",
#           "Gallery",
#           "Game Room",
#           "Games Description",
#           "Garage",
#           "Garage Capacity",
#           "Garage Description",
#           "Garage Spaces",
#           "Garage Type",
#           "Garage/Carport",
#           "Gas",
#           "Gas Available",
#           "Gated",
#           "Grade Level Entry Y/N",
#           "Great Room",
#           "Great Room Description",
#           "HOA Includes",
#           "HOA Pay Schedule",
#           "HOA Terms",
#           "HVAC",
#           "Half Bathrooms",
#           "Heating",
#           "Heating Fuel",
#           "Heating Fuels",
#           "Heating Source",
#           "Heating/Cooling",
#           "Home Features",
#           "Hot Water",
#           "Inclusions",
#           "Income Property",
#           "Insurance Paid By",
#           "Interior",
#           "Interior Features",
#           "Interior Layout",
#           "Interior Maintenance/Repairs Paid By",
#           "Kitchen",
#           "Kitchen Description",
#           "Kitchen Level",
#           "Land Features",
#           "Last Change Type",
#           "Last Updated",
#           "Laundry",
#           "Laundry Description",
#           "Laundry Location",
#           "Laundry Room",
#           "Laundry Room Level",
#           "LaundryFeatures",
#           "Lease",
#           "Lease Includes",
#           "Lease Requirements",
#           "Lease Term",
#           "Lease Type",
#           "Levels",
#           "Library Description",
#           "Listing ID",
#           "Living Area",
#           "Living Description",
#           "Living Room",
#           "Living Room Level",
#           "Loading Dock",
#           "Loading Info",
#           "Location",
#           "Lock Box",
#           "Locker",
#           "Locker Description",
#           "Lot Description",
#           "Lot Features",
#           "Lot Measurement",
#           "Lot Shape",
#           "Lot Size",
#           "Lot Size Source",
#           "MLS",
#           "MLS Area Minor",
#           "MLS\u00ae #",
#           "Maintenance",
#           "Maintenance Paid By",
#           "Major Area",
#           "Management",
#           "Master Bath",
#           "Master Bedroom",
#           "Master Bedroom First Floor",
#           "Master Description",
#           "Media Room",
#           "Media/Ent Description",
#           "Mobile Home Type",
#           "Model Type",
#           "Mortgage Calculator",
#           "Mudroom Description",
#           "Municipality",
#           "N/A",
#           "Natural Gas",
#           "Nearest Town",
#           "Neighbourhood Features",
#           "Number Of Fireplaces",
#           "Nursery Description",
#           "Occupancy",
#           "Occupied By",
#           "Office Description",
#           "Office/Den",
#           "Other",
#           "Out Buildings",
#           "Outdoor Area",
#           "Owner Pays",
#           "Ownership",
#           "Ownership Type",
#           "Pantry Description",
#           "Parking",
#           "Parking Description",
#           "Parking Features",
#           "Parking Spaces",
#           "Parking Surface",
#           "Parking Types",
#           "Partial Bathroom",
#           "Patio",
#           "Percolation Test",
#           "Pet Policy",
#           "Pets Allowed",
#           "Play Description",
#           "Plumbing",
#           "Pool",
#           "Pool Features",
#           "Pool YN",
#           "Possession",
#           "Powder Room Description",
#           "Power",
#           "Power Source",
#           "Present Structures",
#           "Present Use",
#           "Price Type",
#           "Primary Bedrm Level",
#           "Property Details",
#           "Property Sub Type",
#           "Property Subtype",
#           "Property Tax",
#           "Property Type",
#           "Property Type Detail",
#           "Quarter",
#           "Range",
#           "Rear Exposure",
#           "Rec Description",
#           "Recreation",
#           "Recreation Room Level",
#           "Rent Includes",
#           "Rental Equipment",
#           "Rental Features",
#           "Rental Type",
#           "Residence",
#           "Restrictions",
#           "Restrictions/Covenants",
#           "Road",
#           "Road Between Waterfront And Home",
#           "Roof",
#           "Roofing",
#           "Roofing Description",
#           "Room Details",
#           "Rooms",
#           "Sale Rent",
#           "Sale Terms",
#           "Sale Type",
#           "SaleOrRent",
#           "School District",
#           "Security Features",
#           "See less details",
#           "See more details",
#           "Sewer",
#           "Sewer Type",
#           "Showing Instructions",
#           "Sign",
#           "Site Description",
#           "Site Influence",
#           "Site Influences",
#           "Site Information",
#           "Sitting Description",
#           "Smoke Detector(s)",
#           "Soil",
#           "Soil Test",
#           "Solarium Description",
#           "Sprinklers",
#           "SqFT Range",
#           "SqFt Range",
#           "Square Footage",
#           "Status",
#           "Storage Room Level",
#           "Stories",
#           "Storm Sewage Drain",
#           "Structure",
#           "Study Description",
#           "Style",
#           "Sub Area",
#           "Sub Property Type",
#           "Sub Type",
#           "Subdivision",
#           "Sunroom Description",
#           "Surface Water",
#           "Survey Available",
#           "TV Service",
#           "Tandem Description",
#           "Tax Year",
#           "Taxes Paid By",
#           "Telephone Service",
#           "Tenant Pays",
#           "Terms",
#           "Title",
#           "Topography",
#           "Total Acres",
#           "Transaction Type",
#           "Type",
#           "Unnamed: 0",
#           "Utilities",
#           "Utilities Available",
#           "Utilities Included",
#           "Utility Description",
#           "Utility Room",
#           "View",
#           "Walk In Closet Level",
#           "Waste",
#           "Water",
#           "Water Heater",
#           "Water Heater Location",
#           "Water Heating Paid By",
#           "Water Paid By",
#           "Water Purifier",
#           "Water Service",
#           "Water Softener",
#           "Water Source",
#           "Water Treatment",
#           "Water Type",
#           "Water/Sewer",
#           "Waterfront",
#           "Waterfront Features",
#           "Waterfront YN",
#           "Waterview",
#           "Workshop description",
#           "Year Built",
#           "Year Built Description",
#           "Year Built Source",
#           "Yes",
#           "Zoning",
#           "property-baths",
#           "property-sqft"
#         ]
#       }
#     }
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 2048.00it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1423.73it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1211.88it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1034.35it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1779.51it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1227.48it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 934.77it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 754.10it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1743.99it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1095.12it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 883.76it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 775.14it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 3597.17it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 2449.94it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1897.02it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1538.07it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 3248.88it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 2185.67it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1694.67it/s]
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 1381.52it/s]

# %%
# for exp in expectations:
#     result = yt_batch.validate(exp)
#     if not result["success"]:
#         print("❌ Validation failed:")
#         print(result)

# %%
# for exp in expectations:
#     result = modified_yt_batch.validate(exp)
#     if not result["success"]:
#         print("❌ Validation failed:")
#         print(result)
